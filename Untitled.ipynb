# %%
# Import necessary packages

import pandas as pd

# %%
# Reading data and storing in pandas dataframe

df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')
print('dataframe has: {} rows'.format(df.shape[0]))
# Out:
# dataframe has: 79880 rows

# %%
# Selecting a subset of data corresponding to the location Uruguay

uy = df[df["location"] == "Uruguay"]
# Printing first 5 rows
uy.head()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 76157      URY  South America  Uruguay  2020-03-13          4.0        4.0
# 76158      URY  South America  Uruguay  2020-03-14          6.0        2.0
# 76159      URY  South America  Uruguay  2020-03-15          8.0        2.0
# 76160      URY  South America  Uruguay  2020-03-16         29.0       21.0
# 76161      URY  South America  Uruguay  2020-03-17         50.0       21.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 76157                 NaN           NaN         NaN                  NaN  ...
# 76158                 NaN           NaN         NaN                  NaN  ...
# 76159                 NaN           NaN         NaN                  NaN  ...
# 76160                 NaN           NaN         NaN                  NaN  ...
# 76161                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 76157       20551.409              0.1                160.708
# 76158       20551.409              0.1                160.708
# 76159       20551.409              0.1                160.708
# 76160       20551.409              0.1                160.708
# 76161       20551.409              0.1                160.708
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 76157                 6.93            14.0          19.9
# 76158                 6.93            14.0          19.9
# 76159                 6.93            14.0          19.9
# 76160                 6.93            14.0          19.9
# 76161                 6.93            14.0          19.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 76157                     NaN                         2.8            77.91
# 76158                     NaN                         2.8            77.91
# 76159                     NaN                         2.8            77.91
# 76160                     NaN                         2.8            77.91
# 76161                     NaN                         2.8            77.91
#
#        human_development_index
# 76157                    0.817
# 76158                    0.817
# 76159                    0.817
# 76160                    0.817
# 76161                    0.817
#
# [5 rows x 59 columns]

# %%
# How many rows has the new dataframe?
print('dataframe has: {} rows'.format(uy.shape[0]))
# Out:
# dataframe has: 390 rows

# %%
# Display
uy.tail()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 76542      URY  South America  Uruguay  2021-04-02     111568.0     3380.0
# 76543      URY  South America  Uruguay  2021-04-03     113904.0     2336.0
# 76544      URY  South America  Uruguay  2021-04-04     117757.0     3853.0
# 76545      URY  South America  Uruguay  2021-04-05     119958.0     2201.0
# 76546      URY  South America  Uruguay  2021-04-06     123063.0     3105.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 76542            2746.429        1041.0        32.0               23.714  ...
# 76543            2660.857        1071.0        30.0               24.286  ...
# 76544            2907.286        1101.0        30.0               26.571  ...
# 76545            2910.571        1146.0        45.0               31.143  ...
# 76546            2943.143        1191.0        45.0               34.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 76542       20551.409              0.1                160.708
# 76543       20551.409              0.1                160.708
# 76544       20551.409              0.1                160.708
# 76545       20551.409              0.1                160.708
# 76546       20551.409              0.1                160.708
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 76542                 6.93            14.0          19.9
# 76543                 6.93            14.0          19.9
# 76544                 6.93            14.0          19.9
# 76545                 6.93            14.0          19.9
# 76546                 6.93            14.0          19.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 76542                     NaN                         2.8            77.91
# 76543                     NaN                         2.8            77.91
# 76544                     NaN                         2.8            77.91
# 76545                     NaN                         2.8            77.91
# 76546                     NaN                         2.8            77.91
#
#        human_development_index
# 76542                    0.817
# 76543                    0.817
# 76544                    0.817
# 76545                    0.817
# 76546                    0.817
#
# [5 rows x 59 columns]
