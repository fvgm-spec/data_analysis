# %%
# Import necessary packages

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#%%timeit
# Reading data and storing in pandas dataframe

df = pd.read_csv('https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/owid-covid-data.csv')
print('dataframe has: {} rows'.format(df.shape[0]))
# Out:
# dataframe has: 83446 rows

# %%
# Selecting a subset of data corresponding to the location Uruguay

uy = df[df["location"] == "Uruguay"]
# Printing first 5 rows
uy.head()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 79563      URY  South America  Uruguay  2020-03-13          4.0        4.0
# 79564      URY  South America  Uruguay  2020-03-14          6.0        2.0
# 79565      URY  South America  Uruguay  2020-03-15          8.0        2.0
# 79566      URY  South America  Uruguay  2020-03-16         29.0       21.0
# 79567      URY  South America  Uruguay  2020-03-17         50.0       21.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 79563                 NaN           NaN         NaN                  NaN  ...
# 79564                 NaN           NaN         NaN                  NaN  ...
# 79565                 NaN           NaN         NaN                  NaN  ...
# 79566                 NaN           NaN         NaN                  NaN  ...
# 79567                 NaN           NaN         NaN                  NaN  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 79563       20551.409              0.1                160.708
# 79564       20551.409              0.1                160.708
# 79565       20551.409              0.1                160.708
# 79566       20551.409              0.1                160.708
# 79567       20551.409              0.1                160.708
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 79563                 6.93            14.0          19.9
# 79564                 6.93            14.0          19.9
# 79565                 6.93            14.0          19.9
# 79566                 6.93            14.0          19.9
# 79567                 6.93            14.0          19.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 79563                     NaN                         2.8            77.91
# 79564                     NaN                         2.8            77.91
# 79565                     NaN                         2.8            77.91
# 79566                     NaN                         2.8            77.91
# 79567                     NaN                         2.8            77.91
#
#        human_development_index
# 79563                    0.817
# 79564                    0.817
# 79565                    0.817
# 79566                    0.817
# 79567                    0.817
#
# [5 rows x 59 columns]

# %%
# How many rows has the new dataframe?
print('dataframe has: {} rows'.format(uy.shape[0]))
# Out:
# dataframe has: 406 rows

# %%
# Display
uy.tail()
# Out:
#       iso_code      continent location        date  total_cases  new_cases  \
# 79964      URY  South America  Uruguay  2021-04-18     164744.0     2344.0
# 79965      URY  South America  Uruguay  2021-04-19     167033.0     2289.0
# 79966      URY  South America  Uruguay  2021-04-20     169327.0     2294.0
# 79967      URY  South America  Uruguay  2021-04-21     172601.0     3274.0
# 79968      URY  South America  Uruguay  2021-04-22     175891.0     3290.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 79964            2871.714        1908.0        60.0               63.714  ...
# 79965            2837.143        1971.0        63.0               62.571  ...
# 79966            2842.429        2022.0        51.0               61.000  ...
# 79967            2930.286        2083.0        61.0               62.286  ...
# 79968            2770.286        2160.0        77.0               62.000  ...
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 79964       20551.409              0.1                160.708
# 79965       20551.409              0.1                160.708
# 79966       20551.409              0.1                160.708
# 79967       20551.409              0.1                160.708
# 79968       20551.409              0.1                160.708
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 79964                 6.93            14.0          19.9
# 79965                 6.93            14.0          19.9
# 79966                 6.93            14.0          19.9
# 79967                 6.93            14.0          19.9
# 79968                 6.93            14.0          19.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 79964                     NaN                         2.8            77.91
# 79965                     NaN                         2.8            77.91
# 79966                     NaN                         2.8            77.91
# 79967                     NaN                         2.8            77.91
# 79968                     NaN                         2.8            77.91
#
#        human_development_index
# 79964                    0.817
# 79965                    0.817
# 79966                    0.817
# 79967                    0.817
# 79968                    0.817
#
# [5 rows x 59 columns]

# %%
# Creating separate columns for month and year
uy['year'] = pd.DatetimeIndex(uy['date']).year
uy['month'] = pd.DatetimeIndex(uy['date']).month
uy['day'] = pd.DatetimeIndex(uy['date']).day

uy21 = uy[uy["year"] == 2021]

uy21.head()
# Out:
# <ipython-input-7-bf53d5ba5fe9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uy['year'] = pd.DatetimeIndex(uy['date']).year
# <ipython-input-7-bf53d5ba5fe9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uy['month'] = pd.DatetimeIndex(uy['date']).month
# <ipython-input-7-bf53d5ba5fe9>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   uy['day'] = pd.DatetimeIndex(uy['date']).day
#       iso_code      continent location        date  total_cases  new_cases  \
# 79857      URY  South America  Uruguay  2021-01-01      19753.0      634.0
# 79858      URY  South America  Uruguay  2021-01-02      20275.0      522.0
# 79859      URY  South America  Uruguay  2021-01-03      20823.0      548.0
# 79860      URY  South America  Uruguay  2021-01-04      21426.0      603.0
# 79861      URY  South America  Uruguay  2021-01-05      22104.0      678.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 79857             557.857         193.0        12.0                7.143  ...
# 79858             579.571         201.0         8.0                7.714  ...
# 79859             585.000         204.0         3.0                6.571  ...
# 79860             588.571         211.0         7.0                7.286  ...
# 79861             591.714         217.0         6.0                7.000  ...
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 79857                 6.93            14.0          19.9
# 79858                 6.93            14.0          19.9
# 79859                 6.93            14.0          19.9
# 79860                 6.93            14.0          19.9
# 79861                 6.93            14.0          19.9
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 79857                     NaN                         2.8            77.91
# 79858                     NaN                         2.8            77.91
# 79859                     NaN                         2.8            77.91
# 79860                     NaN                         2.8            77.91
# 79861                     NaN                         2.8            77.91
#
#        human_development_index  year  month  day
# 79857                    0.817  2021      1    1
# 79858                    0.817  2021      1    2
# 79859                    0.817  2021      1    3
# 79860                    0.817  2021      1    4
# 79861                    0.817  2021      1    5
#
# [5 rows x 62 columns]

# %%
# How many rows has the new dataframe?
print('dataframe has: {} rows'.format(uy21.shape[0]))
# Out:
# dataframe has: 112 rows

# %%
plt.figure(figsize=(12,10))
plt.xticks(rotation=0)
sns.lineplot(x="day",
            y="new_cases",
            hue="month",
            data=uy21)
plt.ylabel("Casos", size=14)
plt.xlabel("Diasa", size=14)
plt.title("Lineplot", size=16)

# Utilizando la funcion plt.show() se logra visualizar la grafica
plt.show()
